# %% [markdown]
# ### Automible Price Prediction Project

# %% [markdown]
# ### Introduction

# %% [markdown]
# #### Objectives
# - Loading dataset
# - Preprocessing the data
# - Explore feature or charecteristics to predict price of car
# - Develop prediction models
# - Evaluate and refine prediction models

# %% [markdown]
# #### Dataset Description

# %% [markdown]
# #### Source:
#
# - Dataset Name: Automobile Dataset
# - Source: Kaggle
# - Dataset Link: Automobile Dataset on Kaggle (https://www.kaggle.com/datasets/premptk/automobile-data-changed)

# %% [markdown]
# #### Dataset Size:
#
# - The dataset consists of a substantial number of rows and columns, providing a rich source of information for analysis and modeling.

# %% [markdown]
# #### Features (Variables) Included:
# The dataset includes a variety of features (variables) that capture different aspects of automobiles. Some of the key features commonly found in this dataset include:

# %% [markdown]
# 1.  Car ID: A unique identifier for each car.
# 2.  Symboling: A numeric value representing the degree of risk associated with the car.
# 3.  Make: The manufacturer or brand of the car.
# 4.  Fuel Type: The type of fuel used by the car (e.g., gas, diesel).
# 5.  Aspiration: The type of aspiration used in the engine (e.g., std, turbo).
# 6.  Num of Doors: The number of doors in the car.
# 7.  Body Style: The body style of the car (e.g., sedan, hatchback).
# 8.  Drive Wheels: The type of drive wheels (e.g., fwd, rwd, 4wd).
# 9.  Engine Location: The location of the car's engine (e.g., front, rear).
# 10. Wheel Base: The wheelbase of the car.
# 11. Length: The length of the car.
# 12. Width: The width of the car.
# 13. Height: The height of the car.
# 14. Curb Weight: The weight of the car without passengers or cargo.
# 15. Engine Type: The type of engine (e.g., dohc, ohc).
# 16. Num of Cylinders: The number of cylinders in the engine.
# 17. Engine Size: The size of the car's engine.
# 18. Fuel System: The type of fuel system used in the engine.
# 19. Bore: The bore diameter of the engine.
# 20. Stroke: The stroke length of the engine.
# 21. Compression Ratio: The compression ratio of the engine.
# 22. Horsepower: The horsepower of the engine.
# 23. Peak RPM: The peak RPM (revolutions per minute) of the engine.
# 24. City MPG: The city fuel efficiency in miles per gallon.
# 25. Highway MPG: The highway fuel efficiency in miles per gallon.
# 26. Price: The price of the automobile (target variable for prediction).

# %% [markdown]
# #### Sample of the Dataset:
# Below is a sample of rows from the dataset to give readers an idea of its structure:
#
#
# | Car ID | Symboling | Make     | Fuel Type | Aspiration | Num of Doors | Body Style | ... | Horsepower | Peak RPM | City MPG | Highway MPG | Price |
# |--------|-----------|----------|-----------|------------|--------------|------------|-----|------------|----------|----------|-------------|-------|
# | 1      | 3         | alfa-rom | gas       | std        | two          | convertible| ... | 111        | 5000     | 21       | 27          | 13495 |
# | 2      | 3         | alfa-rom | gas       | std        | two          | convertible| ... | 111        | 5000     | 21       | 27          | 16500 |
# | 3      | 1         | alfa-rom | gas       | std        | two          | hatchback  | ... | 154        | 5000     | 19       | 26          | 16500 |
# | 4      | 2         | audi     | gas       | std        | four         | sedan      | ... | 102        | 5500     | 24       | 30          | 13950 |
# | 5      | 2         | audi     | gas       | std        | four         | sedan      | ... | 115        | 5500     | 18       | 22          | 17450 |
# | ...    | ...       | ...      | ...       | ...        | ...          | ...        | ... | ...        | ...      | ...      | ...         | ...   |

# %% [markdown]
# This dataset provides valuable information about various automobile attributes and serves as a valuable resource for building predictive models for automobile prices.

# %%
# Import necesseary libraries
import numpy as np
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('Automobile_data.csv')

# %%
# Show the first 10 rows using dataframe.head() method
print("First 10 rows of the dataframe")
df.head(10)
# Out:
# First 10 rows of the dataframe
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Show the Last 10 rows using dataframe.tail() method
print("Last 10 rows of the dataframe")
df.tail(10)
# Out:
# Last 10 rows of the dataframe
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1                74  volvo       gas        std         four
# 196         -2               103  volvo       gas        std         four
# 197         -1                74  volvo       gas        std         four
# 198         -2               103  volvo       gas      turbo         four
# 199         -1                74  volvo       gas      turbo         four
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Show the 10 random sample rows using dataframe.sample() method
print("10 random sample rows of the dataframe")
df.sample(10)
# Out:
# 10 random sample rows of the dataframe
#      symboling normalized-losses        make fuel-type aspiration  \
# 148          0                85      subaru       gas        std
# 122          1               154    plymouth       gas        std
# 138          2                83      subaru       gas        std
# 197         -1                74       volvo       gas        std
# 130          0                 ?     renault       gas        std
# 88          -1               137  mitsubishi       gas        std
# 163          1               168      toyota       gas        std
# 115          0               161      peugot       gas        std
# 15           0                 ?         bmw       gas        std
# 41           0                85       honda       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 148         four      wagon          4wd           front        96.9  ...
# ...

# %%
# Shape of this dataframe using dataframe.shape() method
print("The dataframe shape(Rows, Columns) is :",df.shape)
# Out:
# The dataframe shape(Rows, Columns) is : (205, 26)

# %% [markdown]
# #### Data Preprocessing
# In preparing the data for modeling in the Automobile Price Prediction Project, several key data preprocessing steps were undertaken to ensure that the dataset was suitable for training and evaluating machine learning models. Here are the steps that were performed:

# %% [markdown]
# - Handling missing values
# - Encoding categorical variables
# - Feature scaling or normalization
# - Data splitting into training and testing sets

# %% [markdown]
# 1. Handling Missing Values:
#
# Identify Missing Data: The first step was to identify columns with missing values in the dataset.
# Imputation: Missing values were imputed using appropriate strategies. Numerical columns with missing values were typically imputed with the mean or median of that column, while categorical columns were imputed with the mode (most frequent category).
# 2. Encoding Categorical Variables:
#
# Conversion to Numeric: Categorical variables (e.g., Make, Fuel Type, Aspiration) were converted into numeric format using techniques such as one-hot encoding. This ensures that machine learning algorithms can work with these variables effectively.
# 3. Feature Scaling or Normalization:
#
# Scaling Numerical Features: Numerical features that had a wide range of values were standardized or scaled to have a mean of 0 and a standard deviation of 1. This step helps algorithms that are sensitive to feature scales, such as gradient descent-based methods.
# 4. Data Splitting into Training and Testing Sets:
#
# Data Division: The dataset was divided into two subsets: a training set and a testing set. The training set was used to train machine learning models, while the testing set was reserved for evaluating model performance.
# Typical Split: A common split ratio is 70-30 or 80-20, where 70% (or 80%) of the data is used for training and the remaining 30% (or 20%) is used for testing.

# %% [markdown]
# ##### Handling Missing Values:
#
# - Identify Missing Data: The first step was to identify columns with missing values in the dataset. Imputation: Missing values were imputed using appropriate strategies. Numerical columns with missing values were typically imputed with the mean or median of that column, while categorical columns were imputed with the mode (most frequent category).

# %% [markdown]
# ##### Convert "?" to NaN
# In the car dataset, missing data comes with the question mark "?". To convert question marks ("?") to NaN (Not a Number) in a pandas DataFrame, you can use the replace method. We replace "?" with NaN (Not a Number), which is Python's default missing value marker, for reasons of computational speed and convenience. Here we use the function:
# -    .replace(A, B, inplace = True)
# to replace A by B
# we can drop missing values along the column "price" as follows

# %%
# Replace "?" with NaN in the entire DataFrame
df.replace("?", np.nan, inplace = True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# Now, the DataFrame contains NaN where there were question marks

# %% [markdown]
# #### Evaluating for Missing Data
# Evaluating missing data is an important step in data preprocessing. we need to identify and handle missing values appropriately before using the data for modeling. In Python, the pandas library provides various functions to help with this task.
#
# There are two methods to detect missing data:
# - .isnull()
# - .notnull()
#
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
# Check for missing values in the entire DataFrame
missing_data = df.isnull()
missing_data
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
# Summarize missing data by column
missing_data_summary = missing_data.sum()
missing_data_summary
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Summarize the percentage of missing data by column
missing_percentage_summary = (missing_data.sum() / len(df)) * 100
missing_percentage_summary
# Out:
# symboling             0.00000
# normalized-losses    20.00000
# make                  0.00000
# fuel-type             0.00000
# aspiration            0.00000
# num-of-doors          0.97561
# body-style            0.00000
# drive-wheels          0.00000
# engine-location       0.00000
# wheel-base            0.00000
# length                0.00000
# width                 0.00000
# height                0.00000
# curb-weight           0.00000
# engine-type           0.00000
# num-of-cylinders      0.00000
# engine-size           0.00000
# fuel-system           0.00000
# bore                  1.95122
# stroke                1.95122
# compression-ratio     0.00000
# horsepower            0.97561
# peak-rpm              0.97561
# city-mpg              0.00000
# highway-mpg           0.00000
# price                 1.95122
# dtype: float64

# %%
# Combine the summaries into a DataFrame for better readability
missing_info = pd.DataFrame({
    'Missing Values': missing_data_summary,
    'Percentage Missing': missing_percentage_summary
})

missing_info
# Out:
#                    Missing Values  Percentage Missing
# symboling                       0             0.00000
# normalized-losses              41            20.00000
# make                            0             0.00000
# fuel-type                       0             0.00000
# aspiration                      0             0.00000
# num-of-doors                    2             0.97561
# body-style                      0             0.00000
# drive-wheels                    0             0.00000
# engine-location                 0             0.00000
# wheel-base                      0             0.00000
# length                          0             0.00000
# width                           0             0.00000
# height                          0             0.00000
# curb-weight                     0             0.00000
# engine-type                     0             0.00000
# num-of-cylinders                0             0.00000
# ...

# %%
# Display columns with missing values
print(missing_info[missing_info['Missing Values'] > 0])
# Out:
#                    Missing Values  Percentage Missing
# normalized-losses              41            20.00000
# num-of-doors                    2             0.97561
# bore                            4             1.95122
# stroke                          4             1.95122
# horsepower                      2             0.97561
# peak-rpm                        2             0.97561
# price                           4             1.95122

# %% [markdown]
# Based on the summary above, each column has 205 rows of data, seven columns containing missing data:
#
# 1. "normalized-losses": 41 missing data points 20% missing values in the column
#
# 2. "num-of-doors": 2 missing data points 0.97% missing values in the column
# 3. "bore": 4 missing data points 1.95% missing values in the column
# 4. "stroke" : 4 missing data points 1.95% missing values in the column
# 5. "horsepower": 2 missing data points 0.97% missing values in the column
# 6. "peak-rpm": 2 missing data points 0.97% missing values in the column
# 7. "price": 4 missing data points 1.95% missing values in the column

# %% [markdown]
# #### First we calculate the average of the column

# %%
# Calculate the average of the normalized-losses column
avg_normalized_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses :", avg_normalized_loss)
# Out:
# Average of normalized-losses : 122.0

# %% [markdown]
# #### Now we replace "NaN" by mean value in "normalized-losses" column

# %%
# Replace NaN values with the mean value
df["normalized-losses"].fillna(avg_normalized_loss, inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# #### We Calculate the mean value in 'bore' column

# %%
# Calculate the average of the "bore" column
avg_bore = df["bore"].astype("float").mean(axis=0)
print("Average of bore : ", avg_bore)
# Out:
# Average of bore :  3.3297512437810957

# %% [markdown]
# #### Replace "NaN" by mean value in "bore" column

# %%
# Replace NaN values with the mean value
df["bore"].replace(np.nan, avg_bore, inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# #### Calculate the mean value in the 'horsepower' column

# %%
# Calculate the average of the "horsepower" column
avg_horsepower = df["horsepower"].astype("float").mean(axis=0)
print("Average horsepower : ", avg_horsepower)
# Out:
# Average horsepower :  104.25615763546799

# %% [markdown]
# #### Replace "NaN" by mean value in "horsepower" column

# %%
# Replace NaN values with the mean value
df["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# #### Calculate the mean value in the 'peak-rpm' column

# %%
# Calculate the average of the "peak-rpm" column
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5125.369458128079

# %% [markdown]
# #### Replace "NaN" by mean value in "peak-rpm" column

# %%
# Replace NaN values with the mean value
df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2             122.0         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1             122.0         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0             122.0         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %% [markdown]
# To see which values are present in a particular column, we can use the ".value_counts()" method:

# %%
# Use value_counts() to count the occurrences of each unique value in the 'num-of-doors' column
df["num-of-doors"].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %% [markdown]
# We can see that four doors are the most common type. We can also use the ".idxmax()" method to calculate for us the most common type automatically:

# %%
# Find the most common value using idxmax()
df["num-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %% [markdown]
# The replacement procedure is very similar to what we have seen previously

# %%
# Replace NaN values by the most frequent value
df["num-of-doors"].fillna("four", inplace = True)
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2             122.0         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1             122.0         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0             122.0         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %% [markdown]
# Finally, let's drop all rows that do not have price data

# %%
# Drop rows with missing values in the 'price' column
df.dropna(subset=["price"], axis=0, inplace = True)

# Reset index because we drop some rows
df.reset_index(drop=True, inplace= True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo       gas      turbo
# 198         -1                95        volvo       gas        std
# 199         -1                95        volvo    diesel      turbo
# 200         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# So now we have 201 rows × 26 columns and we obtain the dataset with no missing value

# %% [markdown]
# ### Currect the data formate

# %% [markdown]
# After dealing with missing values, we check and make sure that all our data is in the correct format like int, float, text, or other.
#
# - To check the data type of a column in Pandas, we can use the .dtype
# - To change the data type of a specific column in a DataFrame, we can use the .astype() method

# %%
# Check the data type of each column
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# In data preprocessing, we examined our dataset for correct data types. It's crucial to ensure that numerical variables are of type 'float' or 'int', while categorical variables with string values should be of type 'object'. We identified columns like 'bore' and 'stroke' meant to represent numerical engine data but were incorrectly labeled as 'object'. To rectify this, we used the Pandas .astype() method to convert these columns to the appropriate data type. This process ensures that our data is structured correctly, facilitating subsequent analysis and modeling. Data accuracy and consistency are essential for generating meaningful insights and predictions.

# %%
# Change the data type of each column to proper format
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Now, Finally we have a cleaned dataset with no missing values and all data in its proper formate.

# %% [markdown]
# ### Data Standardization
# In the context of our project on predicting automobile prices, Data Standardization is a crucial preprocessing step that ensures all numerical features in our dataset have the same scale. This is essential for many machine learning algorithms, as it helps prevent certain features from dominating others due to their larger magnitude.

# %% [markdown]
# #### Why Data Standardization?
# Standardization is necessary when our dataset contains numerical attributes with varying units, scales, and ranges. Without standardization, some features may contribute disproportionately to the predictive model simply because they have larger values, potentially leading to biased results.

# %% [markdown]
# #### The Standardization Process
# The standardization process involves transforming numerical features to have a mean (average) of 0 and a standard deviation of 1. This ensures that all features have a consistent scale.
#
# #### Example of Standardization
#
# Transform mpg to L/100km:
#
# In our dataset, the fuel consumption columns "city-mpg" and "highway-mpg" are represented by mpg (miles per gallon) unit. Assume we are developing an application in a country that accept the fuel consumption with L/100km standard
#
# We will need to apply data transformation to transform mpg into L/100km?
#
# The formula for unit conversion is
#
# L/100km = 235 / mpg
#
# #### Implementation in Python
# We can perform Data Standardization using Python libraries such as pandas and scikit-learn. Here's a step-by-step guide to standardizing our dataset:

# %%
# Check data
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Convert city-mpg to L/100km
df['city-L/100km'] = 235 / df['city-mpg']

# Check transformed data
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %% [markdown]
# ### Data Normalization
# Data normalization is a crucial step in preparing our dataset for machine learning models. It involves scaling the numerical features in the dataset to a standard range. This standardization ensures that all features have the same influence on the machine learning model, preventing one feature from dominating the others due to differences in their scales.

# %% [markdown]
# #### Why Normalize Data?
# Equal Weightage: Normalization ensures that all features contribute equally to the model's learning process.
#
# Faster Convergence: Scaling features to a standard range helps machine learning algorithms converge faster.
#
# Improved Model Performance: Normalization can lead to better performance for models that rely on distance-based metrics, such as K-Nearest Neighbors (KNN) or Principal Component Analysis (PCA).
#
# Methods of Data Normalization
# 1. Min-Max Scaling
# Min-Max scaling scales the data to a specific range, usually between 0 and 1. It's calculated using the formula:
#
# $$ X
# n
# ​
#  ormalized=(X−X
# m
# ​
#  in)/(X
# m
# ​
#  ax−X
# m
# ​
#  in) $$
#
#
# 2. Z-Score Standardization
# Z-Score standardization transforms data to have a mean of 0 and a standard deviation of 1. It's calculated using the formula:
#
# $$ Z=(X−μ)/σ $$
#
#
# Where:
#
# $X$ is the original value.
# $μ$ is the mean of the feature.
# $σ$ is the standard deviation of the feature.
#
# 3. Robust Scaling
# Robust scaling is suitable for data with outliers. It scales data by removing the median and scaling according to the Interquartile Range (IQR).
#
# $$ X
# n
# ​
#  ormalized=(X−X
# m
# ​
#  edian)/IQR $$

# %% [markdown]
# #### Applying Data Normalization
# In our project, we'll apply Min-Max scaling to the numerical columns of the dataset to ensure that they fall within a consistent range.
#
# **Example**
#
# To demonstrate normalization, let's say we want to scale the columns "length", "width" and "height"
#
# **Target:** would like to Normalize those variables so their value ranges from 0 to 1.
#
# **Approach:** replace original value by (original value)/(maximum value)

# %%
# Replace (original value) by (original value)/(maximum value)
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %% [markdown]
# ### Data Binning
# Binning is a data preprocessing technique used to categorize numerical data into discrete bins or intervals. It is particularly useful when dealing with continuous data that you want to convert into categorical data for analysis or visualization.
#
# #### Why Binning?
# 1. Simplify Complex Data: Binning can simplify complex datasets by converting continuous values into discrete categories, making it easier to understand and interpret.
#
# 2. Handling Outliers: Binning can help in handling outliers by grouping extreme values into specific bins, reducing their impact on the analysis.
#
# 3. Feature Engineering: Binned data can serve as a new feature for predictive modeling, capturing patterns that might not be evident in continuous data.
#
# #### Binning Methods
# There are several methods for binning data, and the choice of method depends on the nature of the data and the analysis goals. Here are some common binning methods:
#
# 1. Equal Width Binning: Divides the data into bins of equal width. Suitable when the data distribution is relatively uniform.
#
# 2. Equal Frequency Binning: Divides the data into bins with roughly equal numbers of data points in each bin. Useful for dealing with skewed data distributions.
#
# 3. Clustering-Based Binning: Uses clustering algorithms like k-means to group similar data points into bins.
#
# #### Applying Binning
# In our project, we'll apply binning to specific columns in the dataset to categorize continuous data into discrete intervals. This will help us gain insights and make the data more suitable for analysis.

# %%
# Convert data to correct format
df["horsepower"] = df["horsepower"].astype(int, copy=True)

# %%
import matplotlib.pyplot as plt

# Plotting the histogram
plt.figure(figsize=(8, 6))
plt.hist(df['horsepower'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# Show the plot
plt.show()

# %% [markdown]
# #### Creating Equal-Sized Bins for Horsepower
#
# To simplify our analysis, we want to segment the "horsepower" column into three equal-sized bins. We can achieve this using NumPy's `linspace` function. Here are the steps we'll follow:
#
# 1. Determine the number of bins we want, which in this case is 3.
#
# 2. Calculate the bin width by dividing the range of horsepower values by the number of bins.
#
# 3. Set the starting value for the bins to the minimum value of the "horsepower" column.
#
# 4. Set the ending value for the bins to the maximum value of the "horsepower" column.
#
# 5. Use the `np.linspace` function to generate the bin edges. These edges will define the values at which one bin ends and another begins.
#
# By following these steps, we can effectively segment the "horsepower" column into three bins, making it easier to analyze and interpret the data.

# %%
# Define the number of bins (in this case, 3)
num_bins = 3

# Calculate the bin width by dividing the range of horsepower values by the number of bins
bin_width = (max(df["horsepower"]) - min(df["horsepower"])) / num_bins

# Calculate the bin edges using numpy's linspace function
bin_edges = np.linspace(start=min(df["horsepower"]), stop=max(df["horsepower"]), num=num_bins + 1)

# Create a list of bin labels
bin_labels = ['Low', 'Medium', 'High']

# Use the cut function in pandas to segment the 'horsepower' column into 3 bins
df['horsepower-binned'] = pd.cut(df['horsepower'], bins=bin_edges, labels=bin_labels, include_lowest=True)

# %%
df[['horsepower', 'horsepower-binned']].sample(20)
# Out:
#      horsepower horsepower-binned
# 60           64               Low
# 20           68               Low
# 21           68               Low
# 46          262              High
# 163         116               Low
# 142          82               Low
# 197         160            Medium
# 63           72               Low
# 38           86               Low
# 117          68               Low
# 175         161            Medium
# 10          101               Low
# 177         156            Medium
# 150          62               Low
# 22          102               Low
# 81          145            Medium
# 30           76               Low
# 148          62               Low
# 141         111               Low
# 178          52               Low

# %%
# Let's see the number of vehicles in each bins
df["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %% [markdown]
# Let's visualize the number of vehicles in each bin using Python code and a brief explanation:

# %%
# Plotting a bar to visualize the distribution of vehicles in each bin
plt.bar(bin_labels, df["horsepower-binned"].value_counts())
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# Great job! We successfully narrowed down the intervals for "horsepower" from 57 to 3 categories ("Low," "Medium," and "High") using binning. This simplification will make it much easier to analyze and interpret the data, especially when we want to compare vehicles based on their horsepower characteristics.

# %% [markdown]
# #### Bins visualization
# Using a histogram is a great way to visualize the distribution of the bins that we created for "horsepower." It provides a clear visual representation of how the data is distributed across the three categories: "Low," "Medium," and "High" horsepower.

# %%
# Plotting a histogram to visualize the distribution of vehicles in each bin
plt.hist(df["horsepower-binned"], bins=3, edgecolor="k")

# Adding labels and title to the plot
plt.xlabel("Horsepower Bins")
plt.ylabel("Number of Vehicles")
plt.title("Number of Vehicles in Each Horsepower Bin")

# Displaying the plot
plt.show()

# %% [markdown]
# #### Explanation:
#
# - We use the plt.hist() function from the Matplotlib library to create a histogram.
# - We pass in the "horsepower_bins" column from your dataset as the data to be plotted.
# - The bins parameter is set to 3, as you have divided the data into 3 bins.
# - edgecolor="k" adds black edges to the bars for better visibility.

# %% [markdown]
# ### Indicator Variables
# Indicator variables, also known as dummy variables, are a crucial part of preparing categorical data for analysis. They help convert categorical values into a numerical format that machine learning models can understand. In this section, we'll discuss how to create indicator variables for categorical features in the dataset.
#
# #### Understanding Categorical Data
# Before creating indicator variables, it's essential to understand which features in your dataset are categorical. Categorical features represent discrete values, such as car makes, colors, or categories, and are not suitable for direct numerical analysis. In our dataset, feature like "fuel-type" are categorical. It has two unique values, "gas" or "diesel".
#
# #### Example
# We see the column "fuel-type" has two unique values: "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel type" into indicator variables. We will use Panda's method 'get_dummies' to assign numerical values to different categories of fuel types.
#
# #### Using Pandas' get_dummies
# Pandas, a powerful data manipulation library in Python, provides a convenient function called get_dummies to convert categorical columns into indicator variables. Here's how to use it:

# %%
# See all columns
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-L/100km', 'horsepower-binned'],
#       dtype='object')

# %%
# Assuming 'dummy_variable_01' is your DataFrame
dummy_variable_01 = pd.get_dummies(df["fuel-type"])
dummy_variable_01.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %% [markdown]
#  we've applied get_dummies to the 'fuel-type' column, which will create new columns for each unique category within those features.

# %%
# Rename the columns name "diesel" and "gas"
dummy_variable_01.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_01.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %% [markdown]
# #### Interpreting Indicator Variables
# After applying get_dummies, you'll notice that new columns have been created for each category within the categorical features. These new columns contain binary values (0 or 1) that indicate the presence or absence of a specific category.

# %%
# Merge data frame "df" and "dummy_variable_01"
df = pd.concat([df, dummy_variable_01], axis=1)

# Drop original column "fuel-type" from "df"
df.drop("fuel-type", axis=1, inplace=True)

# %%
# See the sample of our updated dataset
df.sample(10)
# Out:
#      symboling  normalized-losses        make aspiration num-of-doors  \
# 43           2                122       isuzu        std          two
# 40           0                 85       honda        std         four
# 24           1                148       dodge        std         four
# 188          0                122  volkswagen      turbo         four
# 56           1                129       mazda        std          two
# 19           0                 81   chevrolet        std         four
# 168          2                134      toyota        std          two
# 113          0                161      peugot      turbo         four
# 87           1                128      nissan        std          two
# 93           1                122      nissan        std         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 43     hatchback          rwd           front        96.0  0.829409  ...
# ...

# %% [markdown]
# #### Wrapping Up
# Indicator variables are a fundamental step in preparing your dataset for machine learning. By converting categorical data into a numerical format, you make it accessible for various modeling techniques. In the next sections, we'll explore further data transformations and feature engineering techniques to enhance our dataset for modeling.

# %% [markdown]
# ### Analyzing Individual Feature Patterns using Visualization
# In this section, we will explore the process of analyzing individual feature patterns in our dataset through visualization. Visualization is a powerful tool for gaining insights into the characteristics and distributions of specific features or variables. By creating visual representations of data, we can uncover patterns, outliers, and relationships that are essential for data-driven decision-making.

# %%
# Import some Visualization library
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### How to choose the right visualization method?
#
# When selecting the appropriate visualization method for individual variables, it's crucial to consider the nature of the variable in question. Different variable types require distinct visualization approaches to reveal meaningful insights.
#
# For continuous numerical variables, histograms and box plots are effective choices, enabling the examination of data distributions and identifying outliers. Categorical variables, on the other hand, are best represented using bar charts to showcase category frequencies.
#
# The selection of visualization methods should align with the variable's characteristics, ensuring that the chosen approach effectively communicates insights, aids in pattern recognition, and enhances data-driven decision-making processes.

# %%
# Here the list of data types for each columns
print(df.dtypes)
# Out:
# symboling               int64
# normalized-losses       int32
# make                   object
# aspiration             object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower              int32
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# city-L/100km          float64
# horsepower-binned    category
# fuel-type-diesel        uint8
# fuel-type-gas           uint8
# dtype: object

# %% [markdown]
# For example, we can calculate the correlation between variables of type "int64" or "float64" using the method "corr":

# %%
# It's correlation matrix showing how each numerical variable relates to others.
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %% [markdown]
# This will provide a correlation matrix showing how each numerical variable relates to others. The values in the matrix range from -1 to 1, where -1 indicates a strong negative correlation, 1 indicates a strong positive correlation, and 0 indicates no correlation. Analyzing this matrix helps identify relationships between variables and potential predictors for the target variable in tasks like regression analysis.

# %% [markdown]
# #### Continuous Numerical Variables
# Continuous numerical variables, typically of type "int64" or "float64," can take on a wide range of values. To visualize their relationships with other variables, scatterplots with fitted lines are effective tools. The "regplot" function can be employed to create scatterplots with fitted regression lines, aiding in the analysis of linear relationships between individual variables and the price.
#
# For instance, to explore the positive linear relationship between "engine-size" and "price," we can use the following code:

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53216.65530012072)

# %% [markdown]
# The scatterplot of "engine-size" against "price" clearly shows a positive direct correlation between these two variables. As engine size increases, the price tends to go up, indicating that engine size is a valuable predictor of price. The regression line closely resembles a perfect diagonal line, reinforcing this relationship.
#
# To quantify this correlation, we can calculate the correlation coefficient between 'engine-size' and 'price,' which is approximately 0.87. This high positive correlation value further confirms the strong linear relationship between engine size and price in the dataset.

# %%
# Check the correlation between "engine-size" and "price" using .corr method
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# To visualize the relationship between "highway-mpg" and "price," we can create a scatterplot with a fitted regression line using the "regplot" function. This will help us understand the linear association between these two variables. Let's generate the scatterplot:

# %%
#  "highway-mpg" (miles per gallon on the highway) as potential predictor variable of price
sns.regplot(x="highway-mpg", y="price",data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# Indeed, the negative correlation between 'highway-mpg' and 'price' confirms our observation that as highway miles per gallon increases (indicating better fuel efficiency), the price of the vehicle tends to decrease. This insight suggests that fuel-efficient cars are often more affordable, making 'highway-mpg' a valuable predictor of price in our analysis.

# %%
# Check the correlation between "highway=mpg" and "price" using .corr method
df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# #### Week Linear Relationship

# %% [markdown]
# Let's Check if "Peak-rpm" as a predictor variable of "price".

# %%
# "peak-rpm" as predictor variable of price

sns.regplot(x="peak-rpm", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %% [markdown]
# The scatterplot of 'peak-rpm' and 'price' shows no clear linear relationship between these variables. The nearly horizontal regression line and the scattered data points indicate a lack of correlation.
#
# This suggests that 'peak-rpm' is not a reliable predictor of price, as confirmed by its low correlation coefficient of approximately -0.1016. In this case, we should consider excluding 'peak-rpm' from our predictive models, as it doesn't appear to provide valuable information for estimating car prices.

# %%
# Check the correlation between "peak-rpm" and "price" using .corr method
df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# #### Analyzing Categorical Variables with Boxplots
#
# Categorical variables represent characteristics or categories that data units fall into. These variables can be of type "object" or "int64." Visualizing categorical variables is essential for understanding their distribution and impact on the target variable. Boxplots are an effective tool for visualizing the spread and central tendency of categorical data.
#
# #### Boxplots
# Boxplots are a valuable visualization tool for understanding the distribution, central tendency, and variability within categorical data. They allow us to identify outliers, the range of values, and the median of each category.
#
# Let's see the relationship between "body-style" and "price".

# %%
# Create boxplots for "body-style" and "price" categorical variable
sns.boxplot(x="body-style", y="price", data=df)
plt.title('Boxplot of Body Style vs. Price')
plt.xlabel('Body Style')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# We see that the distributions of price between the different body-style categories have a significant overlap, and so body-style would not be a good predictor of price. Let's examine engine "engine-location" and "price":

# %%
# Create boxplots for "engine-location" and "price" categorical variable
sns.boxplot(x="engine-location", y="price", data=df)
plt.title('Boxplot of Engine Location vs. Price')
plt.xlabel('Engine Location')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Here we see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.
#
# Let's examine "drive-wheels" and "price".

# %%
# Create boxplots for "drive-wheels" and "price" categorical variable
sns.boxplot(x="drive-wheels", y="price", data=df)
plt.title('Boxplot of Drive Wheels vs. Price')
plt.xlabel('Drive Wheels')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Here we see that the distribution of price between the different drive-wheels categories differs; as such drive-wheels could potentially be a predictor of price.

# %% [markdown]
# ### Analyzing Descriptive Statistics
#
# In this section, we will explore the descriptive statistics of the dataset to gain insights into its numerical features. Descriptive statistics provide a summary of the main characteristics of the data, helping us understand its central tendencies, variability, and distributions.

# %% [markdown]
# #### Summary Statistics
#
# Let's begin by examining the summary statistics for the key continuous variables in our dataset. The `describe()` function will generate statistics such as:
#
# - Count: The number of non-null values for each variable.
# - Mean: The average value of the variable.
# - Std (Standard Deviation): A measure of the dispersion or spread of the data.
# - Min: The minimum value observed in the variable.
# - 25%: The 25th percentile or the first quartile.
# - 50%: The median or the 50th percentile.
# - 75%: The 75th percentile or the third quartile.
# - Max: The maximum value observed in the variable.
#
# These statistics will provide us with a comprehensive overview of the data's central tendencies and variability.

# %%
# Apply describe() method
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
# The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
# Apply the "describe" method on the 'object' variables
df.describe(include=["object"])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %% [markdown]
# #### Value Counts
#
# In this section, we will explore the distribution of categorical variables in the dataset using the "value_counts" method. This method allows us to understand how many units of each characteristic or category we have within a specific variable.
#
# ##### Drive Wheels Example
#
# As an example, let's apply the "value_counts" method to the 'drive-wheels' column. It's important to note that the "value_counts" method works on Pandas Series, not on Pandas DataFrames. Therefore, we will use one set of brackets, like this: `df['drive-wheels']`, rather than two brackets `df[['drive-wheels']]`.
#
# By examining the value counts of 'drive-wheels', we can gain insights into the distribution of different types of drive wheels in our dataset.

# %%
# Use value_count() method on the 'drive-wheels' variable 
df["drive-wheels"].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %% [markdown]
# Let's convert this series to a Dataframe as follows :

# %%
# Use to_frame() method on the 'drive-wheels' variable for convert into a dataframe
df["drive-wheels"].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "drive_wheels_counts" and rename the column 'drive-wheels' to 'value_counts'.

# %%
# Save into dataframe "drive_wheels_counts" and rename this column 'drive-wheels' to 'value_counts'.
drive_wheels_counts = df["drive-wheels"].value_counts().to_frame()
drive_wheels_counts.rename(columns={"drive-wheels": "value_counts"}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# Now let's rename the index to 'drive-wheels':

# %%
drive_wheels_counts.index.name = "drive-wheels"
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %% [markdown]
# Repeat the above process for the variable 'engine-location' also.

# %%
# Save into dataframe "engine_loc_counts" and rename this column 'engine-location' to 'value_counts'.
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={"engine-location": "value_counts"}, inplace=True)
engine_loc_counts
# Out:
#        value_counts
# front           198
# rear              3

# %% [markdown]
# Rename the index to 'engine-location':

# %%
engine_loc_counts.index.name = "engine-location"
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %% [markdown]
# Examining the value counts of the engine location would not be a good predictor variable for the price. This is because we only have three cars with a rear engine and 198 with an engine in the front, this result is skewed. Thus, we are not able to draw any conclusions about the engine location.

# %% [markdown]
# ### Basics of Grouping
# The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.
#
# For example, let's group by the variable "drive-wheels." We see that there are three different categories of drive wheels: "4wd" (four-wheel drive), "fwd" (front-wheel drive), and "rwd" (rear-wheel drive).
#
# #### Grouping by a Single Variable:
#
# Grouping by a single variable allows us to analyze data within specific categories or classes. In our dataset, grouping by "drive-wheels" enables us to examine how different types of drive wheels impact various automotive attributes like price, horsepower, and fuel efficiency.

# %%
# Find unique values in 'drive-wheels' column using unique() method
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# #### Example:
#
# As an example, let's determine, on average, which type of drive wheel is most valuable. We can achieve this by grouping the data based on "drive-wheels" and calculating the average price within each group. The resulting DataFrame, which includes columns 'drive-wheels,' 'body-style,' and 'price,' will be assigned to the variable "df_group_one."

# %%
# Create 'df_group_one' variable that includes columns like 'drive_wheels', 'body-style' and 'price.
df_group_one = df[['drive-wheels', 'body-style', 'price']]

# %% [markdown]
# #### Aggregate Functions:
# we can calculate the mean(average) price aggregation functions to gain insights of the different categories of data.
#
# mean(): Calculates the mean (average) value of each group.
#
# These functions provide statistical summaries of data within different category, aiding in the exploration of patterns and relationships.

# %%
# Using mean() to find the average price of each drive wheel category
df_group_one = df_group_one.groupby(['drive-wheels'], as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# #### Visualizing Grouped Data:
#
# Visualizing grouped data is crucial for understanding the variations and differences between categories. Visualization techniques, such as bar charts, box plots, or scatter plots, can help in conveying insights effectively.

# %%
# Creating a bar chart to visualize average prices by drive wheel category
df_group_one.plot(kind='bar', title='Average Prices by Drive Wheels')
# Out:
# <AxesSubplot:title={'center':'Average Prices by Drive Wheels'}>

# %% [markdown]
# When analyzing our data, we discover that, on average, rear-wheel drive vehicles tend to be the most expensive, while both four-wheel drive and front-wheel drive vehicles have similar price averages. This insight allows us to understand the impact of the drive-wheel type on pricing.
#
# Additionally, we can harness the power of the "groupby" method to group data using multiple variables, such as 'drive-wheels' and 'body-style.' This approach creates unique combinations, enabling us to delve deeper into the dataset's nuances and uncover intricate patterns.
#
# By exploring these multivariable groupings, we gain a more comprehensive understanding of how different factors interact and influence the outcomes within our data.

# %%
# Create 'df_group_test' variable that includes columns like 'drive_wheels', 'body-style' and 'price.
df_group_test = df[['drive-wheels', 'body-style', 'price']]

# Using mean() to find the average price of each drive wheel and body style category
grouped_test_01 = df_group_test.groupby(['drive-wheels', 'body-style'],as_index=False).mean()
grouped_test_01
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# Creating a pivot table from grouped data simplifies visualization. It's akin to an Excel spreadsheet, where one variable becomes rows, and another becomes columns. We use the "pivot" method to convert the dataframe into a pivot table. In our example, drive-wheel remains the row variable, while body-style becomes the columns. This arrangement makes it easier to grasp and compare data across different categories and variables.

# %%
# Create 'grouped_piovt' variable that includes columns like 'drive_wheels' use the pivot() method to convert the dataframe into a piovt table.
grouped_piovt = grouped_test_01.pivot(index='drive-wheels', columns='body-style')
grouped_piovt
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Often, we won't have data for some of the pivot cells. Missing data in pivot tables can be filled with various values, often with 0. It should be mentioned that missing data is quite a complex subject and is an entire course on its own.

# %%
# Fill missing values with 0
grouped_piovt = grouped_piovt.fillna(0)
grouped_piovt
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# ##### Variables: Drive Wheels and Body Style vs Price
# Let's use a heat map to visualize the relationship between Body Style vs Price.

# %%
# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(grouped_piovt, annot=True, cmap='coolwarm')
plt.title('Heatmap of Body Style vs Price')
plt.show()

# %% [markdown]
# The heatmap plots the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.

# %% [markdown]
# Effective data visualization plays a pivotal role in data science, and Python's visualization libraries offer tremendous flexibility. While we'll delve deeper into visualization techniques in a dedicated Python Visualizations course, our primary focus here is identifying the key determinants of car prices.
#
# To gain insights into these influential factors, we examine the correlation between various variables and car prices. In essence, we're assessing the degree of dependency between each variable and the price of a car.
#
# This analysis enables us to pinpoint the primary characteristics that exert the most significant impact on a car's price, providing valuable insights for decision-making and further analysis in the realm of automotive data science.

# %% [markdown]
# ### Correlation and Causation
#
# #### Correlation:
# Correlation is a statistical measure that gauges the extent of interdependence between two variables, such as X and Y. The Pearson Correlation coefficient produces a value between -1 and 1, signifying the nature of the relationship:
#
# 1: Total positive linear correlation.
# 0: No linear correlation, suggesting the variables likely don't affect each other.
# -1: Total negative linear correlation.
#
# #### Causation:
# Causation, on the other hand, delves into the cause-and-effect relationship between two variables. Determining causation often necessitates independent experimentation and goes beyond correlation.
#
# #### Pearson Correlation:
# We utilize the Pearson Correlation coefficient, accessible via the "corr" function, to measure the linear dependence between 'int64' or 'float64' variables in our dataset.
#
# It's vital to grasp that correlation doesn't imply causation, and discerning causation can be far more complex and challenging.
#
# In the subsequent sections, we will explore the correlation between various variables in our dataset and assess their impact on car prices.
#
# Now, let's proceed to calculate and interpret the Pearson Correlation coefficients.

# %%
# It's correlation matrix showing how each numerical variable relates to others.
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %% [markdown]
# #### P-value:
#
# The P-value, short for probability value, plays a crucial role in statistical analysis when assessing the significance of correlation between two variables. It quantifies the probability that the observed correlation is statistically significant. In typical practice, a significance level of 0.05 is chosen, indicating a 95% confidence level that the correlation is indeed significant.
#
# ##### Interpreting P-values:
#
# - A p-value of 0.001: Strong evidence exists, signifying a highly significant correlation.
# - A p-value of 0.05: Moderate evidence suggests a correlation's significance.
# - A p-value of 0.1: Weak evidence indicates a somewhat significant correlation.
# - A p-value exceeding 0.1: No substantial evidence supports the correlation's significance.
#
# To obtain these p-values, we employ the "stats" module within the "scipy" library, facilitating the rigorous assessment of correlation significance in our data analysis.

# %%
# Import stats library
from scipy import stats

# %% [markdown]
# ##### Wheel-base vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print('The Pearson Correlation Cofficient is', pearson_coef, 'with a P-value of P =', p_value)
# Out:
# The Pearson Correlation Cofficient is 0.584641822265508 with a P-value of P = 8.076488270733218e-20

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585)

# %% [markdown]
# ##### Horsepower vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print('The Pearson Correlation Coefficient is', pearson_coef, 'with a P-value of P = ',p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8096068016571054 with a P-value of P =  6.273536270650504e-48

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between horsepower and price is statistically significant, and the linear relationship is quite strong (~0.809, close to 1)

# %% [markdown]
# ##### Length vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'length' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483639 with a P-value of P =  8.016477466159328e-30

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between length and price is statistically significant, and the linear relationship is moderately strong (~0.691).

# %% [markdown]
# ##### Width vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522673 with a P-value of P = 9.200335510481646e-38

# %% [markdown]
# ##### Conclusion:
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.751).

# %% [markdown]
# ##### Curb-weight vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702843 with a P-value of P =  2.189577238894065e-53

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is quite strong (~0.834).

# %% [markdown]
# ##### Engine-size vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'engine-size' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185 with a P-value of P = 9.265491622198389e-64

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is very strong (~0.872).

# %% [markdown]
# ##### Bore vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'bore' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602 with a P-value of P =   8.049189483935489e-17

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between bore and price is statistically significant, but the linear relationship is only moderate (~0.521).
#
# We can relate the process for each 'City-mpg' and 'Highway-mpg':

# %% [markdown]
# ##### City-mpg vs Price
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'city-mpg' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844678 with a P-value of P =  2.321132065567641e-29

# %% [markdown]
# ##### Conclusion:
# Since the p-value is
#  0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of ~ -0.687 shows that the relationship is negative and moderately strong.

# %% [markdown]
# ##### Highway-mpg vs Price
# Let's calculate the Pearson Correlation Coefficient and P-value of 'highway-mpg' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.704692265058953 with a P-value of P =  1.7495471144476358e-31

# %% [markdown]
# ##### Conclusion:
# Since the p-value is < 0.001, the correlation between highway-mpg and price is statistically significant, and the coefficient of ~ -0.705 shows that the relationship is negative and moderately strong.

# %% [markdown]
# ### ANOVA: Analysis of Variance
# ANOVA is a statistical method used to test for significant differences between the means of two or more groups. It helps determine if variations between groups are due to actual differences or if they could occur by random chance.
#
# #### Parameters Returned by ANOVA
# 1. F-test Score: ANOVA assumes that the means of all groups are equal. The F-test score measures how much the actual means deviate from this assumption. A larger score indicates a greater difference between the means.
#
# 2. P-value: The p-value indicates the statistical significance of the calculated F-test score. A small p-value suggests that the observed differences are unlikely to occur by chance.
#
# #### Applying ANOVA to the Dataset
# In this analysis, we will use ANOVA to examine how different types of 'drive-wheels' impact the 'price' of vehicles. By grouping the data based on drive wheels, we can assess whether there are significant price variations between these groups.
#
# Let's proceed with the ANOVA analysis to uncover any meaningful insights into the relationship between drive wheels and car prices.

# %%
# Group the data by 'drive-wheels' and select the 'price' column
grouped_test_02 = df_group_test[['drive-wheels', 'price']].groupby(['drive-wheels'])

# %%
# Display the first two rows of each group
grouped_test_02.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %%
df_group_test
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %% [markdown]
# We can obtain the values of the method group using the method "get_group".

# %%
grouped_test_02.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %% [markdown]
# we can use the function 'f_oneway' in the module 'stats' to obtain the F-test score and P-value.

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test_02.get_group('fwd')['price'], grouped_test_02.get_group('rwd')['price'], grouped_test_02.get_group('4wd')['price'])
print( "ANOVA results: F=", f_val, ", p=", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , p= 3.3945443577151245e-23

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?

# %% [markdown]
# Separately: fwd and rwd

# %%
f_val, p_val = stats.f_oneway(grouped_test_02.get_group('fwd')['price'], grouped_test_02.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %% [markdown]
# 4wd and rwd

# %%
f_val, p_val = stats.f_oneway(grouped_test_02.get_group('4wd')['price'], grouped_test_02.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %% [markdown]
# 4wd and fwd

# %%
f_val, p_val = stats.f_oneway(grouped_test_02.get_group('4wd')['price'], grouped_test_02.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %% [markdown]
# #### Conclusion: Important Variables
# We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:
#
# Continuous numerical variables:
#
# Length
# Width
# Curb-weight
# Engine-size
# Horsepower
# City-mpg
# Highway-mpg
# Wheel-base
# Bore
#
# Categorical variables:
#
# Drive-wheels
# As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.

# %% [markdown]
# ### Model Development

# %% [markdown]
# In the realm of data analytics, Model Development serves as a pivotal technique for extracting valuable insights from existing data. It enables us to address critical questions such as whether a dealer is providing a fair value for a trade-in and whether a car has been priced reasonably. These questions can be answered by leveraging data-driven approaches to build predictive models.

# %% [markdown]
# A Model will help us understand the exact relationship between different variables and how these variables are used to predict the result.

# %% [markdown]
# #### 1. Linear Regression and and Multiple Linear Regression

# %% [markdown]
# ##### Linear Regression
#
# Linear Regression is a fundamental statistical method used in data analysis to model the relationship between two variables: the predictor (independent) variable, denoted as X, and the response (dependent) variable, which we aim to predict and is represented as Y. The core idea behind Linear Regression is to find a linear function that relates X to Y.
#
# ##### Components of Linear Regression:
#
# 1. Linear Function: In a simple Linear Regression, the model predicts the response variable (Y) as a linear function of the predictor variable (X). This linear function is represented as:
#
#     Y = a + b * X
#
#     "Y" is the predicted value of the response variable.
#     "a" is the y-intercept, indicating the value of Y when X is 0.
#     "b" is the slope of the regression line, signifying the change in Y when X increases by 1 unit.
#
# 2. Purpose: The goal of Linear Regression is to find the best-fitting line that minimizes the difference between the actual data points and the predicted values on the line. This line serves as the basis for making predictions about Y based on given values of X.
#
# 3. Residuals: Residuals are the differences between the actual Y values and the Y values predicted by the linear model. The objective is to minimize these residuals, creating a model that best represents the data.

# %% [markdown]
# #### Lets load the modules for linear regression

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Create the linear regression object

# %%
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %% [markdown]
# ##### Predicting Car Price with Highway-mpg
#
# In this section, we will explore the relationship between the "highway-mpg" (miles per gallon on the highway) and the car's price. We aim to understand how "highway-mpg" can help us predict the price of a car using simple linear regression.

# %% [markdown]
# ##### Understanding Simple Linear Regression
#
# Simple linear regression is a statistical technique used to establish a linear relationship between two variables. In our case, we have:
# - Predictor Variable (Independent Variable): "highway-mpg" (X)
# - Response Variable (Dependent Variable): "price" (Y)
#
# The goal is to create a linear function that predicts the car's price (Y) based on its highway-mpg (X). This function has two key components:
# 1. The intercept (a): It represents the estimated price when highway-mpg is 0.
# 2. The slope (b): It shows how much the price changes for a one-unit increase in highway-mpg.

# %%
X = df[['highway-mpg']]
Y = df[['price']]

# %%
X.head()
# Out:
#    highway-mpg
# 0           27
# 1           27
# 2           26
# 3           30
# 4           22

# %%
Y.head()
# Out:
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0

# %% [markdown]
# Fit the linear model using highway-mpg.

# %%
linear_model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Now, We can output a prediction

# %%
YPred = linear_model.predict(X)

# %%
# Let's see first 10 predictions
YPred[0:10]
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508],
#        [17879.97140011],
#        [17879.97140011],
#        [17879.97140011],
#        [21988.63829172],
#        [14593.03788682]])

# %% [markdown]
# Let's find out the value of the intercept (a)

# %%
linear_model.intercept_
# Out:
# array([38423.30585816])

# %% [markdown]
# Let's see the value of the slope (b)

# %%
linear_model.coef_
# Out:
# array([[-821.73337832]])

# %% [markdown]
# #### What is the final estimated linear model we get?
# As we saw above, we should get a final linear model with the structure:
#
# $$ YPred = a + bX $$
#
# Plugging in the actual values we get:
#
# price = 38423.31 - 821.73 x highway-mpg

# %% [markdown]
# #### 2. Multiple Linear Regression
#
# Multiple Linear Regression is an extension of Simple Linear Regression, where it considers more than one predictor variable to model the relationship with the response variable.
#
# ##### Components of Multiple Linear Regression:
#
# 1. Linear Function: In Multiple Linear Regression, the linear function becomes more complex, accounting for multiple predictor variables:
#
#     Y = a + b1 * X1 + b2 * X2 + ... + bn * Xn
#
#     "Y" is still the predicted value of the response variable.
#     "a" remains the y-intercept.
#     "b1, b2, ..., bn" are the coefficients for each predictor variable (X1, X2, ..., Xn), representing the change in Y associated with a one-unit change in the respective predictor, while other predictors are held constant.
#
# 2. Purpose: Multiple Linear Regression allows us to explore how multiple predictor variables collectively influence the response variable. It enables a more nuanced understanding of the relationships within the data.
#
# 3. Residuals: As in Simple Linear Regression, the objective is to minimize residuals. Multiple Linear Regression aims to find the coefficients that best fit the data by minimizing the difference between observed Y values and the values predicted by the linear combination of the predictor variables.

# %% [markdown]
# $$
# Y: Response \ Variable\\
#
# X_1 :Predictor\ Variable \ 1\\
# X_2: Predictor\ Variable \ 2\\
# X_3: Predictor\ Variable \ 3\\
# X_4: Predictor\ Variable \ 4\\
# $$
#
# $$
# a: intercept\\
#
# b_1 :coefficients \ of\ Variable \ 1\\
# b_2: coefficients \ of\ Variable \ 2\\
# b_3: coefficients \ of\ Variable \ 3\\
# b_4: coefficients \ of\ Variable \ 4\\
# $$
#
# The equation is given by
#
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
#
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
#
# Let's develop a model using these variables as the predictor variables.

# %%
Z = df[['horsepower','curb-weight','engine-size','highway-mpg']]

# %% [markdown]
# Fit the linear model using the four above-mentioned variables.

# %%
linear_model.fit(Z, df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# Let's find out the value of the intercept (a)

# %%
linear_model.intercept_
# Out:
# -15811.863767729232

# %% [markdown]
# Let's see the value of the coefficients(slope) (b1, b2, b3, b4)

# %%
linear_model.coef_
# Out:
# array([53.53022809,  4.70805253, 81.51280006, 36.1593925 ])

# %% [markdown]
#  What is the final estimated linear model that we get?
#
# As we saw above, we should get a final linear function with the structure:
#
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
#
# What is the linear function we get in this example?
#
# <b>Price</b> = -15678.742628061467 + 52.65851272 x <b>horsepower</b> + 4.69878948 x <b>curb-weight</b> + 81.95906216 x <b>engine-size</b> + 33.58258185 x <b>highway-mpg</b>

# %% [markdown]
# ### Model Evaluation using Visualization
#
# Once we've developed various models, the critical question arises: how do we evaluate and select the best model? Visualization plays a crucial role in answering this question.
#
# #### Regression Plot
#
# In the context of simple linear regression, regression plots are a powerful tool for visualizing how well our model fits the data. These plots offer a comprehensive view of the relationship between two variables, helping us assess the correlation's strength and direction.
#
# For our analysis, we will create a regression plot that combines a scatter plot of data points and a fitted linear regression line. This plot will illustrate the potential of "highway-mpg" as a predictor variable of the car's price.
#
# #### Understanding the Regression Plot
#
# The regression plot for "highway-mpg" and "price" serves several purposes:
# - Visualizing Data: It allows us to visualize the distribution of data points.
# - Fitted Line: It includes the linear regression line, which represents the predicted relationship between the variables.
# - Correlation Assessment: We can assess the strength of the correlation between "highway-mpg" and "price" based on the tightness of the data points around the regression line.
# - Direction of Correlation: The direction of the relationship (positive or negative) is revealed by the slope of the regression line.
#
# #### Benefits of Regression Plots
#
# Regression plots are valuable for model evaluation and selection because they provide a visual representation of how well the model aligns with the data. The clearer and more linear the relationship, the better the model is at capturing the underlying patterns.
#
# As we analyze the regression plot for "highway-mpg" and "price," we will gain insights into the potential of "highway-mpg" as a predictor variable for car price.
#
# Let's create the regression plot and interpret the results.

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48160.232264040365)

# %% [markdown]
# #### Interpreting the Regression Plot
#
# Upon examining the regression plot of "highway-mpg" and "price," we can draw several key observations:
#
# - **Negative Correlation:** The regression slope is negative, indicating a negative correlation between "highway-mpg" and "price." As "highway-mpg" increases, the price of the car tends to decrease.
#
# - **Scatter of Data Points:** It's essential to pay close attention to the dispersion of data points around the regression line. The scatter of data points provides valuable insights into the data's variance and the model's suitability. In this context, a scatter with moderate variance may suggest that a linear model is appropriate for the data, while high variance may indicate otherwise.
#
# However, one must be cautious when interpreting the results. If the data points deviate significantly from the regression line, it could indicate that a linear model might not be the best fit for this dataset.
#
# Now, let's compare this regression plot to another, specifically the regression plot of "peak-rpm."

# %%
plt.figure(figsize=(width, height))
sns.regplot(x='peak-rpm', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# #### Comparing Regression Plots: "peak-rpm" vs. "highway-mpg"
#
# In our quest to understand the relationships between variables, let's compare the regression plots of "peak-rpm" and "highway-mpg" to gain further insights:
#
# - **"highway-mpg" Regression Plot:**
#   - The data points for "highway-mpg" are noticeably closer to the generated regression line.
#   - On average, as "highway-mpg" increases, the points tend to decrease. This trend is relatively clear from the plot, indicating a moderate negative correlation.
#
#
#
# - **"peak-rpm" Regression Plot:**
#   - In contrast, the data points for "peak-rpm" exhibit more significant dispersion around the predicted line.
#   - It is challenging to discern a clear trend as the "highway-mpg" increases. The points for "peak-rpm" are spread out, and it's difficult to determine whether they are decreasing or increasing.
#
# These comparisons highlight the variations in data behavior between the two variables. While "highway-mpg" demonstrates a more predictable and negative correlation with price, "peak-rpm" appears to have greater data scatter and a less defined relationship.
#
# Next, we'll delve into more visualizations and analyses to make informed decisions regarding model selection.

# %% [markdown]
# ### Understanding Residual Plots
#
# A fundamental aspect of evaluating regression models is the use of residual plots. Let's delve into what residuals are, why they matter, and what we should pay attention to when examining a residual plot:
#
# **Residuals:** In the context of regression, residuals are the differences between the observed values (y) and the predicted values (Yhat). Mathematically, they are represented as (e = y - Yhat). When we assess a regression plot, these residuals represent the vertical distance from each data point to the fitted regression line.
#
# **Residual Plot:** A residual plot is a graphical representation that displays the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.
#
# **What to Look for in a Residual Plot:**
# - **Spread of Residuals:** When examining a residual plot, we focus on the spread of the residuals.
#
#   - *Random Spread:* If the points in the residual plot appear to be randomly scattered around the x-axis, it indicates that a linear model is suitable for the data. In this context, "randomly spread out" residuals imply that the variance is relatively constant, which aligns with the assumptions of a linear model.
#
#   - *Non-Random Patterns:* Conversely, if the residual points display non-random patterns, such as a funnel shape or an increase in variance, it suggests that the data may violate the assumptions of a linear model. Non-random patterns may indicate the presence of heteroscedasticity or nonlinearity in the data.
#
# Residual plots are invaluable tools for assessing the appropriateness of a linear model for the data and for detecting any issues related to variance or data structure. They play a critical role in model evaluation and selection.
#
# Next, we'll create and analyze residual plots to gain insights into the quality and suitability of our regression models.

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Interpretation of the Residual Plot
#
# This residual plot provides crucial insights into the nature of our data and the suitability of our linear regression model. Here's what this plot is telling us:
#
# **Non-Random Residuals:** The primary observation from this residual plot is that the residuals do not appear to be randomly scattered around the x-axis. Instead, they exhibit a clear pattern that deviates from random spread.
#
# **Potential Non-Linearity:** The presence of non-random patterns in the residuals is an indicator that a non-linear model may be better suited for this dataset. In contrast to linear models, non-linear models can capture the nuances in the relationship between variables that linear models might miss.
#
# **Consideration of Model Selection:** As a result, it's essential to explore non-linear regression models when dealing with this data. These models can accommodate complex relationships between variables and provide a better fit to the underlying structure of the data.
#
# In summary, the non-random spread of residuals in this plot suggests that a non-linear regression model should be considered to capture the underlying patterns within the dataset effectively. The choice of the appropriate regression model will play a critical role in improving the accuracy of our predictions and aligning with the characteristics of the data.

# %% [markdown]
# #### Visualizing a Multiple Linear Regression Model
#
# When working with Multiple Linear Regression, visualizing the model's fit becomes more complex than simple linear regression. However, one way to assess the model's performance is by comparing the distribution of fitted values with the actual values. Here's how you can do it:
#
# ##### Step 1: Make Predictions
#
# First, make predictions using the Multiple Linear Regression model. These predictions represent the model's estimated values based on the input variables.

# %%
Y_Pred = linear_model.predict(Z)

# %% [markdown]
# ##### Step 2: Create Distribution Plots
# Next, create distribution plots to visualize the distribution of both the predicted (fitted) values and the actual values. This comparison helps you assess how well the model's predictions align with the real data.

# %%
# Plot the distributions of actual and predicted values
plt.figure(figsize=(width, height))

ax1 = sns.distplot(df['price'], hist=False, color='r', label='Actual Value')
sns.distplot(Y_Pred, hist=False, color='b', label='Fitted Values', ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that the fitted values are reasonably close to the actual values, since the two distributions overlap a bit. However, there is definitely some room for improvement.
